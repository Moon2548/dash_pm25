# %%
import pandas as pd
import plotly.express as px

# %%
data = pd.read_excel("export-A9D65F26F0B9-1h.xlsx")

# %%
data.plot(x='timestamp', y='pm_2_5', figsize=(12, 6))
# Out:
# <Axes: xlabel='timestamp'>

# %%
fig = px.line(data, x='timestamp', y='pm_2_5')

# %%
eng = pd.read_excel("export-pm25_eng-1d.xlsx")

# %%
eng
# Out:
#      Unnamed: 0               timestamp      timezone   humidity      pm_10  \
# 0             0 2023-04-01 07:00:00.000  Asia/Bangkok  73.861694   4.727273
# 1             1 2023-04-03 07:00:00.000  Asia/Bangkok  67.872493  16.046366
# 2             2 2023-04-04 07:00:00.000  Asia/Bangkok  62.995952  13.300139
# 3             3 2023-04-05 07:00:00.000  Asia/Bangkok  59.482051  11.864336
# 4             4 2023-04-06 07:00:00.000  Asia/Bangkok  66.493574  16.405837
# ..          ...                     ...           ...        ...        ...
# 658         658 2025-02-08 07:00:00.000  Asia/Bangkok  69.348548  30.654249
# 659         659 2025-02-09 07:00:00.000  Asia/Bangkok  69.916384  28.971065
# 660         660 2025-02-10 07:00:00.000  Asia/Bangkok  71.226336  30.652667
# 661         661 2025-02-11 07:00:00.000  Asia/Bangkok  68.159624  32.532955
# 662         662 2025-02-11 11:15:42.468  Asia/Bangkok  76.329751  33.787755
#
#         pm_2_5  pm_2_5_sp  temperature
# ...

# %%
fig = px.line(eng, x='timestamp', y='pm_2_5')
